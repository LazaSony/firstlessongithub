# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import metrics

from sklearn.preprocessing import StandardScaler, MinMaxScaler
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans

# %%
class RegressionPricePrediction():

    def __init__(self):
        df = pd.read_csv("https://raw.githubusercontent.com/rromanss23/Machine_Leaning_Engineer_Udacity_NanoDegree/master/projects/boston_housing/housing.csv")
        df.rename(columns={"RM": "ROOMS",'MEDV': 'PRICE', "LSTAT": "LOWER_CLASS_WORKERS", "PTRATIO": "STUDENT_TEACHER_RATIO"}, inplace=True)
        df.columns = df.columns.str.lower()
        self.df = df

    def sns_pairplot(self):
        return sns.pairplot(data = self.df)
        
    def sns_heatmap(self):
        return sns.heatmap(model.self.corr(),
                            annot=True)

    def sns_target_histogram(self):
        return sns.histplot(data = self.df,
                            x = "price")


        

model = RegressionPricePrediction()
model.sns_heatmap()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_74/4004407414.py in <module>
#      22
#      23 model = RegressionPricePrediction()
# ---> 24 model.sns_heatmap()
#
# /tmp/ipykernel_74/4004407414.py in sns_heatmap(self)
#      11
#      12     def sns_heatmap(self):
# ---> 13         return sns.heatmap(model.corr(),
#      14                             annot=True)
#      15
#
# AttributeError: 'RegressionPricePrediction' object has no attribute 'corr'

# %%
X =  model.df.drop("price", axis=1)
y = model.df["price"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42, shuffle=True)

scaler = MinMaxScaler()
scaler.fit(X_train)

scaled_X_train  = scaler.transform(X_train)
scaled_X_test  = scaler.transform(X_test)
# scaled_X_train, scaled_X_test  = scaler.transform(X_train), scaler.transform(X_test)



print("Training parameters", X_train.shape)
print("Training target", y_train.shape)
print("\nTesting parameters", X_test.shape)l
print("Testing target", y_test.shape)


model_lr = LinearRegression()  # creating model
model_lr.fit(scaled_X_train, y_train) # training model
prediction = model_lr.predict(scaled_X_test) # predict new data
print('MAE:', metrics.mean_absolute_error(y_test, prediction))
# Out:
# Training parameters (342, 3)
# Training target (342,)
#
# Testing parameters (147, 3)
# Testing target (147,)
# MAE: 63313.49737234147

# %% [markdown]
# Without lower_class_workers : 78386.91451412204
#
# student_teacher: 73456.73214527951
#
# rooms: 69142.79541258245
#
# keep all: 63313.49737234147

# %% [markdown]
# # Clustering

# %%
# create dataset
X, y = make_blobs(
   n_samples=150, n_features=2,
   centers=3, cluster_std=0.5,
   shuffle=True, random_state=0
)

# plot
plt.scatter(
   X[:, 0], X[:, 1],
   c='white', marker='o',
   edgecolor='black', s=50
)
plt.show()

# %%
model_k_means = KMeans(n_clusters=3, random_state=0)
model_k_means.fit(X)
y_km = model_k_means.predict(X)

# %%
# plot the 3 clusters
plt.scatter(
    X[y_km == 0, 0], X[y_km == 0, 1],
    s=50, c='lightgreen',
    marker='s', edgecolor='black',
    label='cluster 1'
)

plt.scatter(
    X[y_km == 1, 0], X[y_km == 1, 1],
    s=50, c='orange',
    marker='o', edgecolor='black',
    label='cluster 2'
)

plt.scatter(
    X[y_km == 2, 0], X[y_km == 2, 1],
    s=50, c='lightblue',
    marker='v', edgecolor='black',
    label='cluster 3'
)

# plot the centroids
plt.scatter(
    model_k_means.cluster_centers_[:, 0], model_k_means.cluster_centers_[:, 1],
    s=250, marker='*',
    c='red', edgecolor='black',
    label='centroids'
)
plt.legend(scatterpoints=1)
plt.grid()
plt.show()

# %%
# calculate distortion for a range of number of cluster
distortions = []
for i in range(1, 11):
    km = KMeans(
        n_clusters=i, init='random',
        n_init=10, max_iter=300,
        tol=1e-04, random_state=0
    )
    km.fit(X)
    distortions.append(km.inertia_)

# plot
plt.plot(range(1, 11), distortions, marker='o')
plt.xlabel('Number of clusters')
plt.ylabel('Distortion')
plt.show()

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=7d3ce7c8-a514-49e4-9ba4-a5899ac52ea5' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
